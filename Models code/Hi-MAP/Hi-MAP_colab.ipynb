# %%
# !nvidia-smi
# Out:
# Sun May 10 17:48:47 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh && bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local
# Out:
# --2020-05-10 17:48:54--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  81.12M  94.8MB/s    in 0.9s
#
# 2020-05-10 17:48:55 (94.8 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages')

# %%
# !conda install certifi openssl readline setuptools sqlite tk wheel xz zlib -y
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - certifi
#     - openssl
#     - readline
#     - setuptools
#     - sqlite
#     - tk
#     - wheel
#     - xz
#     - zlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.4.5.1         |           py37_0         155 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     setuptools-46.1.3          |           py37_0         521 KB
#     sqlite-3.31.1              |       h62c20be_1         1.1 MB
#     xz-5.2.5                   |       h7b6447c_0         341 KB
#     ------------------------------------------------------------
#                                            Total:         7.5 MB
#
# The following packages will be UPDATED:
#
# ...

# %%
pip install torch==1.2.0
# Out:
# ...
#      |████████████████████████████████| 748.9 MB 682 bytes/s
# ...
#      |████████████████████████████████| 20.2 MB 1.2 MB/s
# ...

# %%
pip install torchtext
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 14.7 MB/s
# ...

# %%
pip install chardet==3.0.4

# %%
pip install future==0.17.1
# Out:
# ...
#      |████████████████████████████████| 829 kB 9.3 MB/s
# ...
#   Created wheel for future: filename=future-0.17.1-py3-none-any.whl size=488732 sha256=216c033247e3fceda0b5dcd8e55437417dad728fa63657b33ae69429403b20ca
#   Stored in directory: /root/.cache/pip/wheels/16/4c/84/8a6161d44282ede60ed233d090156c6109a7ab865e49c1c9f6
# Successfully built future
# ...

# %%
pip install idna==2.8

# %%
pip install opencv-python==4.0.0.21
# Out:
# ...
#      |████████████████████████████████| 25.4 MB 88 kB/s
# ...

# %%
pip install requests==2.21.0
# Out:
# ...
#      |████████████████████████████████| 57 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 118 kB 27.8 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.8
#     Uninstalling urllib3-1.25.8:
#       Successfully uninstalled urllib3-1.25.8
#   Attempting uninstall: requests
#     Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
# ...

# %%
pip install six==1.12.0
# Out:
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.14.0
#     Uninstalling six-1.14.0:
#       Successfully uninstalled six-1.14.0
# ...

# %%
pip install tqdm==4.31.1
# Out:
# ...
#      |████████████████████████████████| 48 kB 3.2 MB/s
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.42.1
#     Uninstalling tqdm-4.42.1:
#       Successfully uninstalled tqdm-4.42.1
# ...

# %%
pip install urllib3==1.24.1
# Out:
# ...
#      |████████████████████████████████| 118 kB 9.3 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
pip install nltk
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 8.6 MB/s
# ...
#      |████████████████████████████████| 82 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 294 kB 43.9 MB/s
# ...
#      |████████████████████████████████| 676 kB 18.3 MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434674 sha256=4377f50b1247057b22d22dc7238666fc92e344660343b88a353806700ebf23c1
#   Stored in directory: /root/.cache/pip/wheels/45/6c/46/a1865e7ba706b3817f5d1b2ff7ce8996aabdd0d03d47ba0266
# Successfully built nltk
# ...

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python /content/drive/My\ Drive/hi_map/code/preprocess.py \
                    -train_src /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_500/train.src.cleaned.tokenized.truncated500 \
                    -train_tgt /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_500/train.tgt.tokenized  \
                    -valid_src /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_500/val.src.cleaned.tokenized.truncated500    \
                    -valid_tgt /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_500/val.tgt.tokenized    \
                    -save_data /content/drive/My\ Drive/hi_map/data/himap_prep_data \
                    -src_seq_length 10000 \
                    -tgt_seq_length 10000 \
                    -src_seq_length_trunc 500 \
                    -tgt_seq_length_trunc 300 \
                    -dynamic_dict \
                    -share_vocab \
                    -max_shard_size 100000000
# Out:
# [2020-05-08 17:51:15,407 INFO] Extracting features...
# [2020-05-08 17:51:15,420 INFO]  * number of source features: 0.
# [2020-05-08 17:51:15,420 INFO]  * number of target features: 0.
# [2020-05-08 17:51:15,421 INFO] Building `Fields` object...
# [2020-05-08 17:51:15,421 INFO] Building & saving training data...
# [2020-05-08 17:51:15,421 INFO]  * divide corpus into shards and build dataset separately (shard_size = 100000000 bytes).
# [2020-05-08 17:53:02,988 INFO]  * saving train data shard to /content/drive/My Drive/hi_map/data/himap_prep_data.train.1.pt.
# ...

# %%
 # !python /content/drive/My\ Drive/hi_map/code/train.py \
        -data /content/drive/My\ Drive/hi_map/data/himap_prep_data \
        -save_model /content/drive/My\ Drive/hi_map\model_himap_500/himap_colab \
        -copy_attn -accum_count 5 -global_attention mlp -word_vec_size 128 -rnn_size 512  \
        -layers 1 -encoder_type brnn -train_steps 20000 -max_grad_norm 4 -dropout 0. -batch_size 2 \
        -optim adagrad -learning_rate 0.15 -adagrad_accumulator_init 0.1 -reuse_copy_attn -copy_loss_by_seqlength \
        -bridge -seed 777 -world_size 1 -gpu_ranks 0 -save_checkpoint_steps 2000
# Out:
# [2020-05-08 18:06:57,938 INFO]  * vocabulary size. source = 50004; target = 50004
# [2020-05-08 18:06:57,938 INFO] Building model...
# [2020-05-08 18:07:05,554 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 128, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(128, 256, bidirectional=True)
#     (sent_rnn): LSTM(512, 256, bidirectional=True)
#     (bridge): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 128, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#     (rnn): StackedLSTM(
# ...

# %% [markdown]
# Now try with 1000

# %%
# !python /content/drive/My\ Drive/hi_map/code/preprocess.py \
                    -train_src /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_1000/train.src.cleaned.tokenized.truncated1000 \
                    -train_tgt /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_1000/train.tgt.tokenized  \
                    -valid_src /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_1000/val.src.cleaned.tokenized.truncated1000    \
                    -valid_tgt /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_1000/val.tgt.tokenized    \
                    -save_data /content/drive/My\ Drive/hi_map/data/himap_prep_data_1000 \
                    -src_seq_length 10000 \
                    -tgt_seq_length 10000 \
                    -src_seq_length_trunc 1000 \
                    -tgt_seq_length_trunc 300 \
                    -dynamic_dict \
                    -share_vocab \
                    -max_shard_size 100000000
# Out:
# [2020-05-08 21:00:02,002 INFO] Extracting features...
# [2020-05-08 21:00:07,876 INFO]  * number of source features: 0.
# [2020-05-08 21:00:07,877 INFO]  * number of target features: 0.
# [2020-05-08 21:00:07,877 INFO] Building `Fields` object...
# [2020-05-08 21:00:07,877 INFO] Building & saving training data...
# [2020-05-08 21:00:07,878 INFO]  * divide corpus into shards and build dataset separately (shard_size = 100000000 bytes).
# [2020-05-08 21:01:41,100 INFO]  * saving train data shard to /content/drive/My Drive/hi_map/data/himap_prep_data_1000.train.1.pt.
# [2020-05-08 21:04:11,029 INFO]  * saving train data shard to /content/drive/My Drive/hi_map/data/himap_prep_data_1000.train.2.pt.
# [2020-05-08 21:05:24,812 INFO]  * saving train data shard to /content/drive/My Drive/hi_map/data/himap_prep_data_1000.train.3.pt.
# [2020-05-08 21:05:35,771 INFO] Building & saving validation data...
# ...

# %%
 # !python /content/drive/My\ Drive/hi_map/code/train.py \
        -data /content/drive/My\ Drive/hi_map/data/himap_prep_data_1000 \
        -save_model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab \
        -copy_attn -accum_count 5 -global_attention mlp -word_vec_size 128 -rnn_size 512  \
        -layers 1 -encoder_type brnn -train_steps 20000 -max_grad_norm 4 -dropout 0. -batch_size 2 \
        -optim adagrad -learning_rate 0.15 -adagrad_accumulator_init 0.1 -reuse_copy_attn -copy_loss_by_seqlength \
        -bridge -seed 777 -world_size 1 -gpu_ranks 0 -save_checkpoint_steps 2000
# Out:
# [2020-05-08 21:07:43,790 INFO]  * vocabulary size. source = 50004; target = 50004
# [2020-05-08 21:07:43,790 INFO] Building model...
# [2020-05-08 21:07:51,552 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 128, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(128, 256, bidirectional=True)
#     (sent_rnn): LSTM(512, 256, bidirectional=True)
#     (bridge): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 128, padding_idx=1)
#         )
#       )
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#     (rnn): StackedLSTM(
# ...

# %%
 # !python /content/drive/My\ Drive/hi_map/code/train.py \
        -data /content/drive/My\ Drive/hi_map/data/himap_prep_data_1000 \
        -save_model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab \
        -copy_attn -accum_count 5 -global_attention mlp -word_vec_size 128 -rnn_size 512  \
        -layers 1 -encoder_type brnn -train_steps 20000 -max_grad_norm 4 -dropout 0. -batch_size 2 \
        -optim adagrad -learning_rate 0.15 -adagrad_accumulator_init 0.1 -reuse_copy_attn -copy_loss_by_seqlength \
        -bridge -seed 777 -world_size 1 -gpu_ranks 0 -save_checkpoint_steps 2000 -train_from /content/drive/My\ Drive/hi_mapmodel_himap_1000/himap_colab_step_8000.pt
# Out:
# [2020-05-09 07:48:30,513 INFO] Loading checkpoint from /content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_8000.pt
# [2020-05-09 07:48:55,113 INFO] Loading vocab from checkpoint at /content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_8000.pt.
# [2020-05-09 07:48:55,195 INFO]  * vocabulary size. source = 50004; target = 50004
# [2020-05-09 07:48:55,195 INFO] Building model...
# [2020-05-09 07:49:06,847 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 128, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(128, 256, bidirectional=True)
#     (sent_rnn): LSTM(512, 256, bidirectional=True)
#     (bridge): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (decoder): InputFeedRNNDecoder(
# ...

# %%
 # !python /content/drive/My\ Drive/hi_map/code/train.py \
        -data /content/drive/My\ Drive/hi_map/data/himap_prep_data_1000 \
        -save_model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab \
        -copy_attn -accum_count 5 -global_attention mlp -word_vec_size 128 -rnn_size 512  \
        -layers 1 -encoder_type brnn -train_steps 20000 -max_grad_norm 4 -dropout 0. -batch_size 2 \
        -optim adagrad -learning_rate 0.15 -adagrad_accumulator_init 0.1 -reuse_copy_attn -copy_loss_by_seqlength \
        -bridge -seed 777 -world_size 1 -gpu_ranks 0 -save_checkpoint_steps 2000 -train_from /content/drive/My\ Drive/hi_mapmodel_himap_1000/himap_colab_step_12000.pt
# Out:
# [2020-05-09 14:29:10,726 INFO] Loading checkpoint from /content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_12000.pt
# [2020-05-09 14:29:30,895 INFO] Loading vocab from checkpoint at /content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_12000.pt.
# [2020-05-09 14:29:30,989 INFO]  * vocabulary size. source = 50004; target = 50004
# [2020-05-09 14:29:30,990 INFO] Building model...
# [2020-05-09 14:29:40,577 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 128, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(128, 256, bidirectional=True)
#     (sent_rnn): LSTM(512, 256, bidirectional=True)
#     (bridge): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (decoder): InputFeedRNNDecoder(
# ...

# %%
 # !python /content/drive/My\ Drive/hi_map/code/train.py \
        -data /content/drive/My\ Drive/hi_map/data/himap_prep_data_1000 \
        -save_model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab \
        -copy_attn -accum_count 5 -global_attention mlp -word_vec_size 128 -rnn_size 512  \
        -layers 1 -encoder_type brnn -train_steps 20000 -max_grad_norm 4 -dropout 0. -batch_size 2 \
        -optim adagrad -learning_rate 0.15 -adagrad_accumulator_init 0.1 -reuse_copy_attn -copy_loss_by_seqlength \
        -bridge -seed 777 -world_size 1 -gpu_ranks 0 -save_checkpoint_steps 2000 -train_from /content/drive/My\ Drive/hi_mapmodel_himap_1000/himap_colab_step_14000.pt
# Out:
# [2020-05-09 17:31:35,286 INFO] Loading checkpoint from /content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_14000.pt
# [2020-05-09 17:31:57,182 INFO] Loading vocab from checkpoint at /content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_14000.pt.
# [2020-05-09 17:31:57,284 INFO]  * vocabulary size. source = 50004; target = 50004
# [2020-05-09 17:31:57,284 INFO] Building model...
# [2020-05-09 17:32:08,345 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 128, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(128, 256, bidirectional=True)
#     (sent_rnn): LSTM(512, 256, bidirectional=True)
#     (bridge): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#   )
#   (decoder): InputFeedRNNDecoder(
# ...

# %% [markdown]
# Inference

# %%
 # !python /content/drive/My\ Drive/hi_map/code/translate.py -gpu 0 \
        -batch_size 8 \
        -beam_size 4 \
        -model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab_step_20000.pt \
        -src /content/drive/My\ Drive/hi_map/data/multi-news-original-src-cleaned-no-newlinechar-word_tokenizer_1000/test.src.cleaned.tokenized.truncated1000 \
        -output /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab_step_20000_full.output \
        -min_length 200 \
        -max_length 300 \
        -stepwise_penalty \
        -coverage_penalty summary \
        -beta 5 \
        -length_penalty wu \
        -alpha 0.9 \
        -verbose \
        -block_ngram_repeat 3 \
        -ignore_when_blocking "story_separator_special_tag"
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Inference Homicide

# %% [markdown]
# ### top 2 truncated at 1000

# %%
 # !python /content/drive/My\ Drive/hi_map/code/translate.py \
        -batch_size 8 \
        -beam_size 4 \
        -model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab_step_20000.pt \
        -src /content/drive/My\ Drive/hi_map/data/homicide/corpus_2_1000 \
        -output /content/drive/My\ Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_2_1000.output \
        -min_length 100 \
        -max_length 300 \
        -stepwise_penalty \
        -coverage_penalty summary \
        -beta 5 \
        -length_penalty wu \
        -alpha 0.9 \
        -verbose \
        -block_ngram_repeat 3 \
        -ignore_when_blocking "story_separator_special_tag"
# Out:
# Namespace(alpha=0.9, attn_debug=False, batch_size=8, beam_size=4, beta=5.0, block_ngram_repeat=3, coverage_penalty='summary', data_type='text', dump_beam='', dynamic_dict=False, fast=False, gpu=-1, ignore_when_blocking=['story_separator_special_tag'], image_channel_size=3, length_penalty='wu', log_file='', max_length=300, max_sent_length=None, min_length=100, models=['/content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_20000.pt'], n_best=1, output='/content/drive/My Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_2_1000.output', replace_unk=False, report_bleu=False, report_rouge=False, sample_rate=16000, share_vocab=False, src='/content/drive/My Drive/hi_map/data/homicide/corpus_2_1000', src_dir='', stepwise_penalty=True, tgt=None, verbose=True, window='hamming', window_size=0.02, window_stride=0.01)
# ...

# %% [markdown]
# ### top 3 truncated at 1000

# %%
 # !python /content/drive/My\ Drive/hi_map/code/translate.py \
        -batch_size 8 \
        -beam_size 4 \
        -model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab_step_20000.pt \
        -src /content/drive/My\ Drive/hi_map/data/homicide/corpus_3_1000 \
        -output /content/drive/My\ Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_3_1000.output \
        -min_length 100 \
        -max_length 300 \
        -stepwise_penalty \
        -coverage_penalty summary \
        -beta 5 \
        -length_penalty wu \
        -alpha 0.9 \
        -verbose \
        -block_ngram_repeat 3 \
        -ignore_when_blocking "story_separator_special_tag"
# Out:
# Namespace(alpha=0.9, attn_debug=False, batch_size=8, beam_size=4, beta=5.0, block_ngram_repeat=3, coverage_penalty='summary', data_type='text', dump_beam='', dynamic_dict=False, fast=False, gpu=-1, ignore_when_blocking=['story_separator_special_tag'], image_channel_size=3, length_penalty='wu', log_file='', max_length=300, max_sent_length=None, min_length=100, models=['/content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_20000.pt'], n_best=1, output='/content/drive/My Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_3_1000.output', replace_unk=False, report_bleu=False, report_rouge=False, sample_rate=16000, share_vocab=False, src='/content/drive/My Drive/hi_map/data/homicide/corpus_3_1000', src_dir='', stepwise_penalty=True, tgt=None, verbose=True, window='hamming', window_size=0.02, window_stride=0.01)
# ...

# %% [markdown]
# ### top 4 truncated at 1000

# %%
 # !python /content/drive/My\ Drive/hi_map/code/translate.py \
        -batch_size 8 \
        -beam_size 4 \
        -model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab_step_20000.pt \
        -src /content/drive/My\ Drive/hi_map/data/homicide/corpus_4_1000 \
        -output /content/drive/My\ Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_4_1000.output \
        -min_length 100 \
        -max_length 300 \
        -stepwise_penalty \
        -coverage_penalty summary \
        -beta 5 \
        -length_penalty wu \
        -alpha 0.9 \
        -verbose \
        -block_ngram_repeat 3 \
        -ignore_when_blocking "story_separator_special_tag"
# Out:
# Namespace(alpha=0.9, attn_debug=False, batch_size=8, beam_size=4, beta=5.0, block_ngram_repeat=3, coverage_penalty='summary', data_type='text', dump_beam='', dynamic_dict=False, fast=False, gpu=-1, ignore_when_blocking=['story_separator_special_tag'], image_channel_size=3, length_penalty='wu', log_file='', max_length=300, max_sent_length=None, min_length=100, models=['/content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_20000.pt'], n_best=1, output='/content/drive/My Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_4_1000.output', replace_unk=False, report_bleu=False, report_rouge=False, sample_rate=16000, share_vocab=False, src='/content/drive/My Drive/hi_map/data/homicide/corpus_4_1000', src_dir='', stepwise_penalty=True, tgt=None, verbose=True, window='hamming', window_size=0.02, window_stride=0.01)
# ...

# %% [markdown]
# ### top 5 truncated at 1000

# %%
 # !python /content/drive/My\ Drive/hi_map/code/translate.py \
        -batch_size 8 \
        -beam_size 4 \
        -model /content/drive/My\ Drive/hi_map\model_himap_1000/himap_colab_step_20000.pt \
        -src /content/drive/My\ Drive/hi_map/data/homicide/corpus_5_1000 \
        -output /content/drive/My\ Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_5_1000.output \
        -min_length 100 \
        -max_length 300 \
        -stepwise_penalty \
        -coverage_penalty summary \
        -beta 5 \
        -length_penalty wu \
        -alpha 0.9 \
        -verbose \
        -block_ngram_repeat 3 \
        -ignore_when_blocking "story_separator_special_tag"
# Out:
# Namespace(alpha=0.9, attn_debug=False, batch_size=8, beam_size=4, beta=5.0, block_ngram_repeat=3, coverage_penalty='summary', data_type='text', dump_beam='', dynamic_dict=False, fast=False, gpu=-1, ignore_when_blocking=['story_separator_special_tag'], image_channel_size=3, length_penalty='wu', log_file='', max_length=300, max_sent_length=None, min_length=100, models=['/content/drive/My Drive/hi_mapmodel_himap_1000/himap_colab_step_20000.pt'], n_best=1, output='/content/drive/My Drive/hi_map/data/homicide/himap_colab_step_20000_corpus_5_1000.output', replace_unk=False, report_bleu=False, report_rouge=False, sample_rate=16000, share_vocab=False, src='/content/drive/My Drive/hi_map/data/homicide/corpus_5_1000', src_dir='', stepwise_penalty=True, tgt=None, verbose=True, window='hamming', window_size=0.02, window_stride=0.01)
# ...
